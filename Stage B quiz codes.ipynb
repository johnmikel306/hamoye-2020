# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
energy_data = pd.read_csv('energydata_complete.csv')
energy_data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# std        4.069813      2.006111      3.254576      2.042884      4.341321
# min       20.463333     17.200000     28.766667     15.100000     27.660000
# 25%       37.900000     20.790000     36.900000     19.530000     35.530000
# 50%       40.500000     22.100000     38.530000     20.666667     38.400000
# 75%       43.260000     23.290000     41.760000     22.100000     42.156667
# max       56.026667     29.236000     50.163333     26.200000     51.090000
#
#        ...            T9          RH_9         T_out   Press_mm_hg  \
# count  ...  19735.000000  19735.000000  19735.000000  19735.000000
# mean   ...     19.485828     41.552401      7.411665    755.522602
# std    ...      2.014712      4.151497      5.317409      7.399441
# min    ...     14.890000     29.166667     -5.000000    729.300000
# 25%    ...     18.000000     38.500000      3.666667    750.933333
# 50%    ...     19.390000     40.900000      6.916667    756.100000
# 75%    ...     20.600000     44.338095     10.408333    760.933333
# max    ...     24.500000     53.326667     26.100000    772.300000
#
#              RH_out     Windspeed    Visibility     Tdewpoint           rv1  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      79.750418      4.039752     38.330834      3.760707     24.988033
# std       14.901088      2.451221     11.794719      4.194648     14.496634
# min       24.000000      0.000000      1.000000     -6.600000      0.005322
# 25%       70.333333      2.000000     29.000000      0.900000     12.497889
# 50%       83.666667      3.666667     40.000000      3.433333     24.897653
# 75%       91.666667      5.500000     40.000000      6.566667     37.583769
# max      100.000000     14.000000     66.000000     15.500000     49.996530
#
#                 rv2
# count  19735.000000
# mean      24.988033
# std       14.496634
# min        0.005322
# 25%       12.497889
# 50%       24.897653
# 75%       37.583769
# max       49.996530
#
# [8 rows x 28 columns]

# %%
column_names = {'T1': 'Temperature in kitchen area','RH_1': 'Humidity in kitchen area','T2': 'Temperature in living room area',
    'RH_2': 'Humidity in living room area','T3': 'Temperature in laundry room area','RH_3': 'Humidity in laundry room area',
    'T4': 'Temperature in office room','RH_4': 'Humidity in office room','T5': 'Temperature in bathroom',
    'RH_5': 'Humidity in bathroom','T6': 'Temperature outside the building (north side)',
    'RH_6': 'Humidity outside the building (north side)','T7': 'Temperature in ironing room','RH_7': 'Humidity in ironing room',
    'T8': 'Temperature in teenager room 2','RH_8': 'Humidity in teenager room 2','T9': 'Temperature in parents room',
    'RH_9': 'Humidity in parents room','T_out': 'Temperature outside (from Chievres weather station)',
    'RH_out': 'Humidity outside (from Chievres weather station)','rv1': 'Random variable 1','rv2': 'Random variable 2',}

# %%
energy_data = energy_data.rename(columns = column_names)
energy_data
# Out:
#                       date  Appliances  lights  Temperature in kitchen area  \
# 0      2016-01-11 17:00:00          60      30                    19.890000
# 1      2016-01-11 17:10:00          60      30                    19.890000
# 2      2016-01-11 17:20:00          50      30                    19.890000
# 3      2016-01-11 17:30:00          50      40                    19.890000
# 4      2016-01-11 17:40:00          60      40                    19.890000
# ...                    ...         ...     ...                          ...
# 19730  2016-05-27 17:20:00         100       0                    25.566667
# 19731  2016-05-27 17:30:00          90       0                    25.500000
# 19732  2016-05-27 17:40:00         270      10                    25.500000
# 19733  2016-05-27 17:50:00         420      10                    25.500000
# 19734  2016-05-27 18:00:00         430      10                    25.500000
#
#        Humidity in kitchen area  Temperature in living room area  \
# 0                     47.596667                        19.200000
# 1                     46.693333                        19.200000
# 2                     46.300000                        19.200000
# 3                     46.066667                        19.200000
# 4                     46.333333                        19.200000
# ...                         ...                              ...
# 19730                 46.560000                        25.890000
# 19731                 46.500000                        25.754000
# 19732                 46.596667                        25.628571
# 19733                 46.990000                        25.414000
# 19734                 46.600000                        25.264286
#
#        Humidity in living room area  Temperature in laundry room area  \
# 0                         44.790000                         19.790000
# 1                         44.722500                         19.790000
# 2                         44.626667                         19.790000
# 3                         44.590000                         19.790000
# 4                         44.530000                         19.790000
# ...                             ...                               ...
# 19730                     42.025714                         27.200000
# 19731                     42.080000                         27.133333
# 19732                     42.768571                         27.050000
# 19733                     43.036000                         26.890000
# 19734                     42.971429                         26.823333
#
#        Humidity in laundry room area  Temperature in office room  ...  \
# 0                          44.730000                   19.000000  ...
# 1                          44.790000                   19.000000  ...
# 2                          44.933333                   18.926667  ...
# 3                          45.000000                   18.890000  ...
# 4                          45.000000                   18.890000  ...
# ...                              ...                         ...  ...
# 19730                      41.163333                   24.700000  ...
# 19731                      41.223333                   24.700000  ...
# 19732                      41.690000                   24.700000  ...
# 19733                      41.290000                   24.700000  ...
# 19734                      41.156667                   24.700000  ...
#
#        Temperature in parents room  Humidity in parents room  \
# 0                        17.033333                   45.5300
# 1                        17.066667                   45.5600
# 2                        17.000000                   45.5000
# 3                        17.000000                   45.4000
# 4                        17.000000                   45.4000
# ...                            ...                       ...
# 19730                    23.200000                   46.7900
# 19731                    23.200000                   46.7900
# 19732                    23.200000                   46.7900
# 19733                    23.200000                   46.8175
# 19734                    23.200000                   46.8450
#
#        Temperature outside (from Chievres weather station)  Press_mm_hg  \
# 0                                               6.600000          733.5
# 1                                               6.483333          733.6
# 2                                               6.366667          733.7
# 3                                               6.250000          733.8
# 4                                               6.133333          733.9
# ...                                                  ...            ...
# 19730                                          22.733333          755.2
# 19731                                          22.600000          755.2
# 19732                                          22.466667          755.2
# 19733                                          22.333333          755.2
# 19734                                          22.200000          755.2
#
#        Humidity outside (from Chievres weather station)  Windspeed  \
# 0                                             92.000000   7.000000
# 1                                             92.000000   6.666667
# 2                                             92.000000   6.333333
# 3                                             92.000000   6.000000
# 4                                             92.000000   5.666667
# ...                                                 ...        ...
# 19730                                         55.666667   3.333333
# 19731                                         56.000000   3.500000
# 19732                                         56.333333   3.666667
# 19733                                         56.666667   3.833333
# 19734                                         57.000000   4.000000
#
#        Visibility  Tdewpoint  Random variable 1  Random variable 2
# 0       63.000000   5.300000          13.275433          13.275433
# 1       59.166667   5.200000          18.606195          18.606195
# 2       55.333333   5.100000          28.642668          28.642668
# 3       51.500000   5.000000          45.410389          45.410389
# 4       47.666667   4.900000          10.084097          10.084097
# ...           ...        ...                ...                ...
# 19730   23.666667  13.333333          43.096812          43.096812
# 19731   24.500000  13.300000          49.282940          49.282940
# 19732   25.333333  13.266667          29.199117          29.199117
# 19733   26.166667  13.233333           6.322784           6.322784
# 19734   27.000000  13.200000          34.118851          34.118851
#
# [19735 rows x 29 columns]

# %%
simple_linear_reg_df = energy_data [['Temperature in living room area', 'Temperature outside the building (north side)']].sample(15, random_state=2)
simple_linear_reg_df
# Out:
#        Temperature in living room area  \
# 1117                         17.426667
# 16275                        22.760000
# 13272                        21.230000
# 3160                         21.100000
# 19210                        21.856667
# 8260                         17.356667
# 12299                        19.000000
# 13505                        22.700000
# 12913                        19.593333
# 17788                        21.890000
# 17894                        21.500000
# 7665                         19.142857
# 10165                        18.000000
# 18809                        22.400000
# 8737                         17.066667
#
#        Temperature outside the building (north side)
# 1117                                       -4.238889
# 16275                                      14.690000
# 13272                                       8.926667
# 3160                                        7.690000
# 19210                                      10.800000
# 8260                                        5.000000
# 12299                                       5.300000
# 13505                                      17.133333
# 12913                                       7.545000
# 17788                                       9.190000
# 17894                                       5.160000
# 7665                                        0.937500
# 10165                                       0.200000
# 18809                                      16.833333
# 8737                                        1.900000

# %%
energy_data.drop('date', axis=1, inplace=True)
energy_data
# Out:
#        Appliances  lights  Temperature in kitchen area  \
# 0              60      30                    19.890000
# 1              60      30                    19.890000
# 2              50      30                    19.890000
# 3              50      40                    19.890000
# 4              60      40                    19.890000
# ...           ...     ...                          ...
# 19730         100       0                    25.566667
# 19731          90       0                    25.500000
# 19732         270      10                    25.500000
# 19733         420      10                    25.500000
# 19734         430      10                    25.500000
#
#        Humidity in kitchen area  Temperature in living room area  \
# 0                     47.596667                        19.200000
# 1                     46.693333                        19.200000
# 2                     46.300000                        19.200000
# 3                     46.066667                        19.200000
# 4                     46.333333                        19.200000
# ...                         ...                              ...
# 19730                 46.560000                        25.890000
# 19731                 46.500000                        25.754000
# 19732                 46.596667                        25.628571
# 19733                 46.990000                        25.414000
# 19734                 46.600000                        25.264286
#
#        Humidity in living room area  Temperature in laundry room area  \
# 0                         44.790000                         19.790000
# 1                         44.722500                         19.790000
# 2                         44.626667                         19.790000
# 3                         44.590000                         19.790000
# 4                         44.530000                         19.790000
# ...                             ...                               ...
# 19730                     42.025714                         27.200000
# 19731                     42.080000                         27.133333
# 19732                     42.768571                         27.050000
# 19733                     43.036000                         26.890000
# 19734                     42.971429                         26.823333
#
#        Humidity in laundry room area  Temperature in office room  \
# 0                          44.730000                   19.000000
# 1                          44.790000                   19.000000
# 2                          44.933333                   18.926667
# 3                          45.000000                   18.890000
# 4                          45.000000                   18.890000
# ...                              ...                         ...
# 19730                      41.163333                   24.700000
# 19731                      41.223333                   24.700000
# 19732                      41.690000                   24.700000
# 19733                      41.290000                   24.700000
# 19734                      41.156667                   24.700000
#
#        Humidity in office room  ...  Temperature in parents room  \
# 0                    45.566667  ...                    17.033333
# 1                    45.992500  ...                    17.066667
# 2                    45.890000  ...                    17.000000
# 3                    45.723333  ...                    17.000000
# 4                    45.530000  ...                    17.000000
# ...                        ...  ...                          ...
# 19730                45.590000  ...                    23.200000
# 19731                45.590000  ...                    23.200000
# 19732                45.730000  ...                    23.200000
# 19733                45.790000  ...                    23.200000
# 19734                45.963333  ...                    23.200000
#
#        Humidity in parents room  \
# 0                       45.5300
# 1                       45.5600
# 2                       45.5000
# 3                       45.4000
# 4                       45.4000
# ...                         ...
# 19730                   46.7900
# 19731                   46.7900
# 19732                   46.7900
# 19733                   46.8175
# 19734                   46.8450
#
#        Temperature outside (from Chievres weather station)  Press_mm_hg  \
# 0                                               6.600000          733.5
# 1                                               6.483333          733.6
# 2                                               6.366667          733.7
# 3                                               6.250000          733.8
# 4                                               6.133333          733.9
# ...                                                  ...            ...
# 19730                                          22.733333          755.2
# 19731                                          22.600000          755.2
# 19732                                          22.466667          755.2
# 19733                                          22.333333          755.2
# 19734                                          22.200000          755.2
#
#        Humidity outside (from Chievres weather station)  Windspeed  \
# 0                                             92.000000   7.000000
# 1                                             92.000000   6.666667
# 2                                             92.000000   6.333333
# 3                                             92.000000   6.000000
# 4                                             92.000000   5.666667
# ...                                                 ...        ...
# 19730                                         55.666667   3.333333
# 19731                                         56.000000   3.500000
# 19732                                         56.333333   3.666667
# 19733                                         56.666667   3.833333
# 19734                                         57.000000   4.000000
#
#        Visibility  Tdewpoint  Random variable 1  Random variable 2
# 0       63.000000   5.300000          13.275433          13.275433
# 1       59.166667   5.200000          18.606195          18.606195
# 2       55.333333   5.100000          28.642668          28.642668
# 3       51.500000   5.000000          45.410389          45.410389
# 4       47.666667   4.900000          10.084097          10.084097
# ...           ...        ...                ...                ...
# 19730   23.666667  13.333333          43.096812          43.096812
# 19731   24.500000  13.300000          49.282940          49.282940
# 19732   25.333333  13.266667          29.199117          29.199117
# 19733   26.166667  13.233333           6.322784           6.322784
# 19734   27.000000  13.200000          34.118851          34.118851
#
# [19735 rows x 28 columns]

# %%
#Firstly, we normalise our dataset to a common scale using the min max scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_energy_data = pd.DataFrame(scaler.fit_transform(energy_data), columns=energy_data.columns)
features_data = normalised_energy_data[['Temperature in living room area']]
target_variable = normalised_df['Temperature outside the building (north side)']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features_data, target_variable, test_size=0.3, random_state=42)

reg_model = LinearRegression()
reg_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = reg_model.predict(X_test)

# %%
reg_model.coef_.round(2)
# Out:
# array([0.89])

# %%
reg_model.intercept_
# Out:
# 0.13176427761888437

# %%
# r^2
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, y_pred)
round(r2_score, 2)
# Out:
# 0.64

# %%
#MAE
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
round(mae, 2)
# Out:
# 0.08

# %%
# residual sum of squares
import numpy as np
rss = np.sum(np.square(y_test - y_pred)).round(2)
rss
# Out:
# 66.12

# %%
# Root Mean Squared Error
from sklearn.metrics import  mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred)).round(2)
rmse
# Out:
# 0.11

# %%
X = energy_data.drop(columns=['Temperature outside the building (north side)'])

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, target_variable, test_size=0.3, random_state=42)

reg_model = LinearRegression()
reg_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.5)
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
#comparing the effects of regularisation
def get_weights_df(model, feat, col_name):
  #this function returns the weight of every feature
  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ['Features', col_name]
  weights_df[col_name].round(3)
  return weights_df

reg_model_weights = get_weights_df(reg_model, X_train, 'reg_model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, X_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, X_train, 'Lasso_weight')

final_weights = pd.merge(reg_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')
final_weights
# Out:
#                                              Features  reg_model_Weight  \
# 0                         Temperature in kitchen area         -0.021179
# 1                             Temperature in bathroom         -0.006561
# 2                                           Tdewpoint         -0.004197
# 3                         Temperature in ironing room         -0.004013
# 4                      Temperature in teenager room 2         -0.003683
# 5                       Humidity in laundry room area         -0.003594
# 6                          Temperature in office room         -0.002561
# 7                         Humidity in teenager room 2         -0.001446
# 8          Humidity outside the building (north side)         -0.000970
# 9                            Humidity in kitchen area         -0.000940
# 10                                        Press_mm_hg         -0.000454
# 11                                          Windspeed         -0.000097
# 12                               Humidity in bathroom         -0.000062
# 13                                         Visibility         -0.000015
# 14                                  Random variable 1         -0.000004
# 15                                  Random variable 2         -0.000004
# 16                                         Appliances          0.000024
# 17                                             lights          0.000125
# 18                           Humidity in ironing room          0.000366
# 19                           Humidity in parents room          0.000654
# 20                            Humidity in office room          0.001368
# 21                   Temperature in laundry room area          0.001644
# 22   Humidity outside (from Chievres weather station)          0.001881
# 23                       Humidity in living room area          0.002926
# 24                        Temperature in parents room          0.008797
# 25                    Temperature in living room area          0.023553
# 26  Temperature outside (from Chievres weather sta...          0.032250
#
#     Ridge_Weight  Lasso_weight
# 0      -0.021172 -1.543655e-02
# 1      -0.006560 -3.021143e-03
# 2      -0.004191  0.000000e+00
# 3      -0.004013 -1.230546e-04
# 4      -0.003684 -3.768612e-03
# 5      -0.003593 -2.263523e-03
# 6      -0.002561 -5.818849e-04
# 7      -0.001446 -1.172509e-03
# 8      -0.000970 -1.054805e-03
# 9      -0.000938  7.584887e-04
# 10     -0.000454 -5.337468e-04
# 11     -0.000097 -0.000000e+00
# 12     -0.000062 -1.715534e-04
# 13     -0.000015 -8.123762e-06
# 14     -0.000004 -1.433746e-06
# 15     -0.000004 -4.885425e-21
# 16      0.000024  2.403390e-05
# 17      0.000125 -0.000000e+00
# 18      0.000366 -0.000000e+00
# 19      0.000654  6.086048e-04
# 20      0.001368  1.394989e-03
# 21      0.001643  0.000000e+00
# 22      0.001880  1.336577e-03
# 23      0.002923  0.000000e+00
# 24      0.008796  1.238951e-03
# 25      0.023546  1.633038e-02
# 26      0.032244  2.923823e-02
