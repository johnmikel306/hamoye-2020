# %%
#extent function
a = [1,2,3,4,5,6]
b = [13,21,34]

a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %%
import numpy as np

# %%
#creating an identity matrix
f = np.eye(3)
print(f)

np.identity(3)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
import pandas as pd
import numpy as np
import

# %%
dt = pd.read_csv('fuel_ferc1.csv')
dt
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
a = dt.iloc[:,[4,10]]
a
# Out:
#       fuel_type_code_pudl  fuel_cost_per_mmbtu
# 0                    coal                1.121
# 1                    coal                1.120
# 2                    coal                1.650
# 3                    coal                1.970
# 4                     gas                2.570
# ...                   ...                  ...
# 29518                 gas                9.030
# 29519                 gas                6.950
# 29520                 gas                8.990
# 29521                coal                1.110
# 29522                 gas               11.680
#
# [29523 rows x 2 columns]

# %%
a.describe()
# Out:
#        fuel_cost_per_mmbtu
# count         29523.000000
# mean             19.304354
# std            2091.540939
# min             -41.501000
# 25%               1.940000
# 50%               4.127000
# 75%               7.745000
# max          359278.000000

# %%
b = dt.iloc[:,[7]]

# %%
b
# Out:
#        fuel_mmbtu_per_unit
# 0                   16.590
# 1                   16.592
# 2                   24.130
# 3                   23.950
# 4                    1.000
# ...                    ...
# 29518                1.059
# 29519                1.050
# 29520                1.060
# 29521               16.108
# 29522                1.059
#
# [29523 rows x 1 columns]

# %%
#standard deviation and 75th percentile of measure of energy per unit 
b.describe().round(2)
# Out:
#        fuel_mmbtu_per_unit
# count             29523.00
# mean                  8.49
# std                  10.60
# min                   0.00
# 25%                   1.02
# 50%                   5.76
# 75%                  17.01
# max                 341.26

# %%
c = dt.iloc[:,[6]]
c
# Out:
#        fuel_qty_burned
# 0            5377489.0
# 1           10486945.0
# 2            2978683.0
# 3            3739484.0
# 4              40533.0
# ...                ...
# 29518          18799.0
# 29519         806730.0
# 29520         104554.0
# 29521         315945.0
# 29522          17853.0
#
# [29523 rows x 1 columns]

# %%
c.mean()
# Out:
# fuel_qty_burned    2.622119e+06
# dtype: float64

# %%
dt.values
# Out:
# array([['f1_fuel_1994_12_1_0_7', 1, 1994, ..., 18.59, 18.53, 1.121],
#        ['f1_fuel_1994_12_1_0_10', 1, 1994, ..., 18.58, 18.53, 1.12],
#        ['f1_fuel_1994_12_2_0_1', 2, 1994, ..., 39.72, 38.12, 1.65],
#        ...,
#        ['f1_fuel_2018_12_12_1_10', 12, 2018, ..., 4.77, 4.77, 8.99],
#        ['f1_fuel_2018_12_12_1_13', 12, 2018, ..., 3.06, 14.76, 1.11],
#        ['f1_fuel_2018_12_12_1_14', 12, 2018, ..., 0.0, 0.0, 11.68]],
#       dtype=object)

# %%
dt.skew(axis=0, skipna= True)
# Out:
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %%
dt.kurt()
# Out:
# utility_id_ferc1                    1.088432
# report_year                        -1.145656
# fuel_qty_burned                   651.369450
# fuel_mmbtu_per_unit                55.595695
# fuel_cost_per_unit_burned         485.255851
# fuel_cost_per_unit_delivered    11765.054226
# fuel_cost_per_mmbtu             29489.132594
# dtype: float64

# %%
#fuel type with the lowest average fuel cost per unit burned
dt.groupby('fuel_type_code_pudl').mean().round(2)
# Out:
#                      utility_id_ferc1  report_year  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                           115.64      2004.62       1903472.81
# gas                            124.12      2005.98       4843182.72
# nuclear                        107.40      2002.97       5454838.43
# oil                            113.24      2007.20         63116.77
# other                          110.47      2001.70       2948136.61
# waste                          154.25      2005.65        117191.36
#
#                      fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# fuel_type_code_pudl
# coal                               20.76                      67.42
# gas                                 1.02                      13.66
# nuclear                            17.58                    4955.16
# oil                                 5.81                     168.88
# other                               0.57                      18.25
# ...

# %%
#fuel type with the lowest average fuel cost per unit burned
dt.groupby('fuel_type_code_pudl').fuel_cost_per_unit_burned.mean()
# Out:
# fuel_type_code_pudl
# coal         67.421830
# gas          13.659397
# nuclear    4955.157002
# oil         168.877086
# other        18.253856
# waste        19.518122
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
# %matplotlib inline

# %%
dt.groupby('fuel_type_code_pudl').fuel_cost_per_unit_burned.mean().plot(kind = 'bar')

# %%
dt.head(10)
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
# 5  f1_fuel_1994_12_2_0_13                 2         1994
# 6   f1_fuel_1994_12_2_1_1                 2         1994
# 7  f1_fuel_1994_12_2_1_10                 2         1994
# 8  f1_fuel_1994_12_2_2_10                 2         1994
# 9   f1_fuel_1994_12_4_0_1                 4         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# ...

# %%
dt['fuel_mmbtu_per_unit']
# Out:
# 0        16.590
# 1        16.592
# 2        24.130
# 3        23.950
# 4         1.000
#           ...
# 29518     1.059
# 29519     1.050
# 29520     1.060
# 29521    16.108
# 29522     1.059
# Name: fuel_mmbtu_per_unit, Length: 29523, dtype: float64

# %%
dt.fuel_mmbtu_per_unit.describe().round(2)
# Out:
# count    29523.00
# mean         8.49
# std         10.60
# min          0.00
# 25%          1.02
# 50%          5.76
# 75%         17.01
# max        341.26
# Name: fuel_mmbtu_per_unit, dtype: float64

# %%
dt.fuel_cost_per_mmbtu.describe()
# Out:
# count     29523.000000
# mean         19.304354
# std        2091.540939
# min         -41.501000
# 25%           1.940000
# 50%           4.127000
# 75%           7.745000
# max      359278.000000
# Name: fuel_cost_per_mmbtu, dtype: float64

# %%
# year with the highest average fuel cost per unit delivered
highest_year = dt.groupby('report_year').fuel_cost_per_unit_delivered.mean()

highest_year.sort_values(ascending=False)
# Out:
# report_year
# 1997    11140.197239
# 1996     9196.705948
# 2000      985.362877
# 2009      652.694163
# 2018      499.269966
# 2015      326.535511
# 1998      287.154420
# 2014      192.737183
# 2013      172.307591
# 2004      139.524275
# 2016      103.901761
# 2010       91.862105
# 1994       63.636060
# 2012       60.994502
# 2001       60.050396
# 2011       59.774667
# 2008       58.588197
# 2003       55.663493
# 2002       47.594361
# 2017       46.196861
# 2007       43.325023
# 2005       41.438184
# 2006       38.657484
# 1995       32.735269
# 1999       25.551627
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %%
#skewness and kurtosis of fuel qty burned
skewness = round(dt.fuel_qty_burned.skew(), 2)
print(skewness)
kurtosiss= dt.fuel_qty_burned.kurt().round(2)
kurtosiss
# Out:
# 15.85
# 651.37

# %%
#total number of missing values
print(dt.isnull().sum())

#percentage of missing values
dt.isnull().mean().round(4)*100
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64
# record_id                       0.00
# utility_id_ferc1                0.00
# report_year                     0.00
# plant_name_ferc1                0.00
# fuel_type_code_pudl             0.00
# fuel_unit                       0.61
# fuel_qty_burned                 0.00
# fuel_mmbtu_per_unit             0.00
# fuel_cost_per_unit_burned       0.00
# fuel_cost_per_unit_delivered    0.00
# fuel_cost_per_mmbtu             0.00
# dtype: float64

# %%
#correlation
dt.corr().round(2)
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                          1.00         0.09            -0.06
# report_year                               0.09         1.00             0.01
# fuel_qty_burned                          -0.06         0.01             1.00
# fuel_mmbtu_per_unit                      -0.07        -0.11            -0.08
# fuel_cost_per_unit_burned                -0.04         0.01            -0.02
# fuel_cost_per_unit_delivered             -0.02        -0.01            -0.00
# fuel_cost_per_mmbtu                       0.01         0.01            -0.00
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                            -0.07                      -0.04
# report_year                                 -0.11                       0.01
# fuel_qty_burned                             -0.08                      -0.02
# ...

# %%
# %matplotlib inline
dt.corr().plot(kind = 'bar')

# %%
#percent = ((1998cost - 1994cost)/ 1994cost)*100

dt.groupby(['fuel_type_code_pudl','report_year'])['fuel_unit'].count()['coal'].pct_change()
# Out:
# report_year
# 1994         NaN
# 1995   -0.012793
# 1996   -0.079914
# 1997   -0.021127
# 1998    0.026379
# 1999   -0.009346
# 2000   -0.051887
# 2001   -0.104478
# 2002   -0.086111
# 2003   -0.003040
# 2004   -0.021341
# 2005    0.000000
# 2006    0.018692
# 2007    0.009174
# 2008   -0.024242
# 2009   -0.012422
# 2010   -0.009434
# 2011    0.022222
# 2012    0.012422
# 2013   -0.021472
# 2014   -0.078370
# 2015   -0.091837
# 2016   -0.116105
# 2017   -0.059322
# 2018   -0.054054
# Name: fuel_unit, dtype: float64
